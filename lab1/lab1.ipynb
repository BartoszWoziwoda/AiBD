# %% [markdown]
# ## Bartosz Woziwoda- AiBD, gr. 3a
#
# ### Lab 1

# %% [markdown]
# ## Zadanie 3
# Zdefiniuj poniższą funkcję i sporządź jej wykres dla argumentów z danego przedziału:
#
# $f(x)=x^2+5$
#
#     $x>-1 oraz x<1$
#     $x>-6 oraz x<6$
#     $x>0 oraz x<5$
#
# Wspierając się dokumentacją Matplotlib. Dodaj do wykresu etykiety osi, tytuły wykresów i legendy.
#
# Wskazówki: Deklaracja funkcji w Python.
#
# W Pythonie bloki kodu (w tym również funkcje) są wyróżniane za pomocą wcięć. Do wizualizacji wyników w Pythonie używa się pakietu Matplotlib.
#
# W pliku mają być zawarte: imię, nazwisko, opis wykonywanego ćwiczenia - formatowanie markdown w poszczególnych komórkach.

# %% [markdown]
# **Import pakietów**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Zdefiniowanie funkcji**

# %%
def func(x):
    return x**2 + 5

# %% [markdown]
# **Utworzenie zmiennych**

# %%
x1 = np.linspace(-1,1,100)
x2 = np.linspace(-6,6,100)
x3 = np.linspace(0,5,100)
y1 = func(x1)
y2 = func(x2)
y3 = func(x3)

# %% [markdown]
# **Wyrysowanie i konfiguracja wykresów**

# %%
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.plot(x1,y1,'r')
plt.grid()
plt.xlabel("Oś X")
plt.ylabel("Oś Y")
plt.legend(["f(x)  = x^2 + 5"])

plt.subplot(132)
plt.plot(x2,y2,'b')
plt.grid()
plt.xlabel("Oś X")
plt.ylabel("Oś Y")
plt.legend(["f(x)  = x^2 + 5"])

plt.subplot(133)
plt.plot(x3,y3,'g')
plt.grid()
plt.xlabel("Oś X")
plt.ylabel("Oś Y")
plt.legend(["f(x) = x^2 + 5"])

plt.show()

# %% [markdown]
# ## Zadanie 4

# %% [markdown]
# Utwórz dataframe, w którym kolumny mają nazwy: name, surname, age, sex. Uzupełnij pięcioma dowolnymi rekordami oraz wyświetl informacje o danych pandas inf, opis danych pandas describe, wyświetl pierwsze trzy rekordy pandas head.

# %% [markdown]
# **Import biblioteki pandas**

# %%
import pandas as pd

# %% [markdown]
# **Utworzenie dataframe**

# %%
data = {'name': ['Robert','Jan','Andrzej','Król','Henryk'], 
        'surname': ['Makłowicz','Paweł','Duda','Julian','Sienkiewicz'],
        'age': [58,2,13,14,175]
        ,'sex': ['M','M','M','M','M']}

df = pd.DataFrame(data)
print(df)
# Out:
#       name      surname  age sex
# 0   Robert    Makłowicz   58   M
# 1      Jan        Paweł    2   M
# 2  Andrzej         Duda   13   M
# 3     Król       Julian   14   M
# 4   Henryk  Sienkiewicz  175   M

# %% [markdown]
# **Wyświetlenie informacji za pomocą funkcji info() oraz describe()**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   surname  5 non-null      object
#  2   age      5 non-null      int64
#  3   sex      5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 288.0+ bytes

# %%
df.describe()
# Out:
#               age
# count    5.000000
# mean    52.400000
# std     71.814344
# min      2.000000
# 25%     13.000000
# 50%     14.000000
# 75%     58.000000
# max    175.000000

# %%
df.head(3)
# Out:
#       name    surname  age sex
# 0   Robert  Makłowicz   58   M
# 1      Jan      Paweł    2   M
# 2  Andrzej       Duda   13   M
